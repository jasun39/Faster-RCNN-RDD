# %%
from models.create_fasterrcnn_model import create_model
from models.model_summary import summary
import yaml
import torch

with open('config/rdd.yaml', 'r') as file:
        config = yaml.safe_load(file)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
test_config = config['test_params']

checkpoint = torch.load(test_config['weights_path'], map_location=device)
build_model = create_model['fasterrcnn_resnet50_fpn']
model = build_model(num_classes=test_config['num_classes'])
#model.load_state_dict(checkpoint)
model.to(device)
print(summary(model))
# Out:
# ...
# Layer (type (var_name))                                 Input Shape               Output Shape              Param #                   Param %                   Kernel Shape
# ...
# FasterRCNN (FasterRCNN)                                 [4, 3, 640, 640]          [100, 4]                  --                             --                   --
# ├─GeneralizedRCNNTransform (transform)                  [4, 3, 640, 640]          [4, 3, 800, 800]          --                             --                   --
# ├─BackboneWithFPN (backbone)                            [4, 3, 800, 800]          [4, 256, 13, 13]          --                             --                   --
# │    └─IntermediateLayerGetter (body)                   [4, 3, 800, 800]          [4, 2048, 25, 25]         --                             --                   --
# ...
